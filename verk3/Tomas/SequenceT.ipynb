# %% [markdown]
# ## Testing area for SequenceActorTomas.py

# %%
from SequenceActorTomas import SequenceEnv
env = SequenceEnv()

# %%
env.play_full_game(policy="random", verbose=True)
# Out:
# no_feasible_move = 0  player = 1  cards in deck = 5  last played card at coords: ( 1 5 ) sequences: [2, 1] sequence discs: {(4, 4), (3, 8), (2, 2), (3, 4), (0, 4), (0, 0), (1, 5), (3, 7), (1, 1), (3, 3), (3, 9), (2, 6), (4, 8), (3, 6), (5, 9), (3, 5)}

# %%
for i in range(1000):
  env.play_full_game(verbose=False)

# %%
for i in range(10):
  wins = env.learn(policy=('greedy', 'greedy'), episodes=1000, verbose=True)
  print(f'training: {wins}')
  wins = env.learn2(policy=('greedy', 'random'), episodes=500, verbose=True)
  print(f'greedy 1: {wins}')
  wins = env.learn2(policy=('random', 'greedy'), episodes=500, verbose=True)
  print(f'greedy 2: {wins}')
# Out:
# [=
# /home/tomas/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py:264: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   delta = torch.tensor(delta, dtype = torch.float, device=self.device)
# ===================] Finished 1000 episodes
# training: [493, 485]
# [====================] Finished 500 episodes
# greedy 1: [293, 199]
# [====================] Finished 500 episodes
# greedy 2: [209, 290]
# [====================] Finished 1000 episodes
# training: [525, 465]
# [====================] Finished 500 episodes
# greedy 1: [289, 201]
# [====================] Finished 500 episodes
# greedy 2: [213, 281]
# [==
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_46973/413490306.py in <module>
#       1 for i in range(10):
# ----> 2   wins = env.learn(policy=('greedy', 'greedy'), episodes=1000, verbose=True)
#       3   print(f'training: {wins}')
#       4   wins = env.learn2(policy=('greedy', 'random'), episodes=500, verbose=True)
#       5   print(f'greedy 1: {wins}')
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in learn(self, policy, episodes, verbose)
#     735             self.old_value[1] = y_sigmoid
#     736
# --> 737             w = self.make_move(policy)
#     738
#     739             while w == -1:
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in make_move(self, policy)
#     348             for i in range(len(legal_moves)):
#     349                 x1, x2 = legal_moves[i]
# --> 350                 x[:,t] = self.lookahead_attributes(legal_moves[i], self.cards_on_board[x1,x2], self.player)
#     351                 t += 1
#     352             for i in range(len(legal_moves_1J)):
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in lookahead_attributes(self, pos, card, disc)
#     212         card_index = np.where(self.hand[p] == card)[0][0]
#     213         self.hand[p][card_index] = -1
# --> 214         self.update_attributes(pos=pos, old_card=card, new_card=self.hand[p][card_index])
#     215         attr = self.attributes[p].copy()
#     216
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in update_attributes(self, pos, old_card, new_card)
#     625                 new_attr = np.zeros(3)
#     626                 new_attr[disc] = 1
# --> 627                 self.attributes[k][attr_pos:attr_pos+3] = new_attr
#     628                 disc = 3 - disc
#     629
#
# KeyboardInterrupt:

# %%
for i in range(10):
  wins = env.learn(policy=('greedy', 'greedy'), episodes=10000, verbose=True)
  print(f'training: {wins}')
  wins = env.learn2(policy=('greedy', 'random'), episodes=1000, verbose=True)
  print(f'greedy 1: {wins}')
  wins = env.learn2(policy=('random', 'greedy'), episodes=1000, verbose=True)
  print(f'greedy 2: {wins}')
# Out:
# [====================] Finished 10000 episodes
# training: [5150, 4655]
# [====================] Finished 1000 episodes
# greedy 1: [539, 443]
# [====================] Finished 1000 episodes
# greedy 2: [516, 464]
# [=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_54124/3425351479.py in <module>
#       1 for i in range(10):
# ----> 2   wins = env.learn(policy=('greedy', 'greedy'), episodes=10000, verbose=True)
#       3   print(f'training: {wins}')
#       4   wins = env.learn2(policy=('greedy', 'random'), episodes=1000, verbose=True)
#       5   print(f'greedy 1: {wins}')
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in learn(self, policy, episodes, verbose)
#     750                 self.old_value[p] = y_sigmoid
#     751
# --> 752                 w = self.make_move(policy)
#     753
#     754             if w == 1:
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in make_move(self, policy)
#     355                 t += 1
#     356             for i in range(len(legal_moves_2J)):
# --> 357                 x[:,t] = self.lookahead_attributes(legal_moves_2J[i], 49, self.player)
#     358                 t += 1
#     359
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in lookahead_attributes(self, pos, card, disc)
#     212         card_index = np.where(self.hand[p] == card)[0][0]
#     213         self.hand[p][card_index] = -1
# --> 214         self.update_attributes(pos=pos, old_card=card, new_card=self.hand[p][card_index])
#     215         attr = self.attributes[p].copy()
#     216
#
# ~/Forritun/Python/IÐN102M/Teymi5-TV2/verk3/Tomas/SequenceActorTomas.py in update_attributes(self, pos, old_card, new_card)
#     623         else:
#     624             for k in range(2):
# --> 625                 new_attr = np.zeros(3)
#     626                 new_attr[disc] = 1
#     627                 self.attributes[k][attr_pos:attr_pos+3] = new_attr
#
# KeyboardInterrupt:
